# %% [markdown]
# 引入相关包

# %%
import sys
import os
import numpy as np
from datetime import datetime
import glob
#Get the path of the current file
current_path = os.getcwd()
# Add the evoman_framework folder to sys.path
sys.path.append(os.path.join(current_path, "evoman"))
# Now you can import contents from the evoman environment
from evoman.environment import Environment
from evoman.controller import Controller
# Initialize environment

# %% [markdown]
# 创建目录

# %%
# Set headless mode to improve running speed
headless = True
if headless:
    os.environ["SDL_VIDEODRIVER"] = "dummy"

experiment_name = "single_island_optimization"
test_log_path = 'single_island_optimization/test_logs/'
module_path = 'single_island_optimization/models/' 
if not os.path.exists(experiment_name):
    os.makedirs(experiment_name)

if not os.path.exists(test_log_path):
    os.makedirs(test_log_path)

if not os.path.exists(module_path):
    os.makedirs(module_path)

# %% [markdown]
# 定义控制器

# %%
# Define Sigmoid activation function
def sigmoid_activation(x):
    return 1.0 / (1.0 + np.exp(-x))
# Custom controller with a simple neural network structure
class player_controller(Controller):
    def __init__(self, _n_hidden):
        self.n_hidden = [_n_hidden]  # Number of neurons in the hidden layer

    def set(self, controller, n_inputs):
        if self.n_hidden[0] > 0:
            # Extract weights and biases from controller parameters to build the neural network
            self.bias1 = controller[: self.n_hidden[0]].reshape(1, self.n_hidden[0])
            weights1_slice = n_inputs * self.n_hidden[0] + self.n_hidden[0]
            self.weights1 = controller[self.n_hidden[0] : weights1_slice].reshape(
                (n_inputs, self.n_hidden[0])
            )
            self.bias2 = controller[weights1_slice : weights1_slice + 5].reshape(1, 5)
            self.weights2 = controller[weights1_slice + 5 :].reshape(
                (self.n_hidden[0], 5)
            )

    def control(self, inputs, controller):
        # Normalize inputs
        inputs = (inputs - min(inputs)) / float((max(inputs) - min(inputs)))
        if self.n_hidden[0] > 0:
            output1 = sigmoid_activation(inputs.dot(self.weights1) + self.bias1)
            output = sigmoid_activation(output1.dot(self.weights2) + self.bias2)[0]
        else:
            bias = controller[:5].reshape(1, 5)
            weights = controller[5:].reshape((len(inputs), 5))
            output = sigmoid_activation(inputs.dot(weights) + bias)[0]

        # Determine player actions based on output
        left = 1 if output[0] > 0.5 else 0
        right = 1 if output[1] > 0.5 else 0
        jump = 1 if output[2] > 0.5 else 0
        shoot = 1 if output[3] > 0.5 else 0
        release = 1 if output[4] > 0.5 else 0

        return [left, right, jump, shoot, release]


# Initialize controller
player_controller_instance = player_controller(10)  # Example with 10 hidden neurons

# %% [markdown]
# 定义相关函数

# %%
# Run simulation and return fitness
def simulation(env, x):
    #env.player_controller.set(x, n_inputs)  # Set controller parameters
    f, _, _, _ = env.play(pcont=x)
    return f

# Evaluate population
def evaluate(x):
    return np.array([simulation(env, ind) for ind in x])

# Initialize population
def initialize_population():
    pop = np.random.uniform(dom_l, dom_u, (npop, n_vars))
    fit_pop = evaluate(pop)
    return pop, fit_pop

# Uniform crossover
def uniform_crossover(p1, p2):
    offspring = np.zeros_like(p1)
    for i in range(len(p1)):
        if np.random.rand() < 0.5:
            offspring[i] = p1[i]
        else:
            offspring[i] = p2[i]
    return offspring

# Fixed mutation
def mutation_operation(offspring):
    for i in range(len(offspring)):
        if np.random.uniform(0, 1) <= mutation:
            offspring[i] += np.random.normal(0, 1)
    return offspring

# Crossover and mutation operations
def crossover_and_mutation(pop):
    total_offspring = np.zeros((0, n_vars))
    for p in range(0, pop.shape[0], 2):
        p1 = pop[np.random.randint(0, pop.shape[0])]
        p2 = pop[np.random.randint(0, pop.shape[0])]

        # Uniform crossover
        offspring = uniform_crossover(p1, p2)

        # Fixed mutation operation
        offspring = mutation_operation(offspring)

        # Fitness constraint
        offspring = np.clip(offspring, dom_l, dom_u)
        total_offspring = np.vstack((total_offspring, offspring))

    return total_offspring

# Elitism selection
def elitism(pop, fit_pop, elite_size):
    elite_indices = np.argsort(fit_pop)[-elite_size:]
    elite_pop = pop[elite_indices]
    elite_fitness = fit_pop[elite_indices]
    return elite_pop, elite_fitness


# Genetic algorithm evolution process
def evolve_population(pop, fit_pop):
    # Elitism selection
    elite_size = int(elitism_rate * npop)
    elite_pop, elite_fitness = elitism(pop, fit_pop, elite_size)

    # Crossover and mutation
    offspring = crossover_and_mutation(pop)
    fit_offspring = evaluate(offspring)

    # Combine elites and offspring
    pop = np.vstack((elite_pop, offspring[: npop - elite_size]))
    fit_pop = np.hstack((elite_fitness, fit_offspring[: npop - elite_size]))

    return pop, fit_pop

# Save final solution
def save_final_solution(
    pop, fit_pop, experiment_name, enemies, npop, gens, mutation, elitism_rate
):
    best_index = np.argmax(fit_pop)
    best_solution = pop[best_index]
    best_fitness = fit_pop[best_index]

    # Get current timestamp
    current_time = datetime.now().strftime("%Y%m%d_%H%M%S")

    # Filename uses the best fitness, population size, generations, enemy type, mutation rate, and elitism rate
    filename = (
        f"{experiment_name}/models/SIModel_fitness{best_fitness:.6f}_npop{npop}_gens{gens}_"
        f"enemy{enemies}_mut{mutation:.2f}_elitism{elitism_rate:.2f}_{current_time}.txt"
    )

    # Save the best individual's controller weights and biases
    np.savetxt(filename, best_solution)

    # Print information about the saved file
    print(f"Best solution saved as {filename} with fitness: {best_fitness:.6f}")

# Run evolution process
def run_evolution():
    current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"{experiment_name}/test_logs/SI_log_{current_time}.txt"

    with open(filename, "a") as file:
        # Write header row
        file.write(
            f"npop{npop}_gens{gens}_"
            f"enemy{env.enemies}_mut{mutation:.2f}_elitism{elitism_rate:.2f}_{current_time}\n"
        )
        file.write("gen best mean std\n")

        pop, fit_pop = initialize_population()

        for generation in range(gens):
            pop, fit_pop = evolve_population(pop, fit_pop)

            # Record results
            best = np.max(fit_pop)  # Best value
            mean = np.mean(fit_pop)  # Mean value
            std = np.std(fit_pop)  # Standard deviation

            result = f"{generation} {best:.6f} {mean:.6f} {std:.6f}"
            print(result)

            # Write to file
            file.write(result + "\n")

        # Save the final best solution
        save_final_solution(
            pop, fit_pop, experiment_name, env.enemies, npop, gens, mutation, elitism_rate
        )


# Load best solution
def load_best_solution(filepath):
    return np.loadtxt(filepath)

# Simulation test
def simulation_test(env, x):
    env.player_controller.set(x, n_inputs)  # Set controller parameters
    f, player_life, enemy_life, _ = env.play(pcont=x)  # Return player and enemy life
    return f, player_life, enemy_life

# %% [markdown]
# 初始化环境

# %%
env = Environment(
    experiment_name=experiment_name,
    multiplemode="yes",
    playermode="ai",
    player_controller=player_controller_instance,
    enemymode="static",
    level=2,
    speed="fastest",
    visuals=False,
)
# Out:
# MESSAGE: Pygame initialized for simulation.
# shm_open() failed: No such file or directory
# ALSA lib conf.c:4028:(snd_config_hooks_call) Cannot open shared library libasound_module_conf_pulse.so (/home/taoyida/miniconda3/envs/EC/lib/alsa-lib/libasound_module_conf_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib pcm.c:2722:(snd_pcm_open_noupdate) Unknown PCM default

# %% [markdown]
# 超参数

# %%
#set your enemy here
env.enemies=[5,6,7,8]

# Genetic algorithm parameters
n_inputs = 20  # Number of inputs to the controller
n_vars = (
    n_inputs * 10 + 10 + 10 * 5 + 5
)  # Total number of weights and biases in the controller
dom_u = 1
dom_l = -1
npop = 100  # Population size
gens = 100  # Total generations
mutation = 0.2  # Mutation rate
elitism_rate = 0.2  # Elitism rate

# %% [markdown]
# 训练

# %%
for i in range(10):
    print(f"Running evolution iteration {i+1}")
    run_evolution()
# Out:
# Running evolution iteration 1
# 0 56.136246 -0.345932 12.070850
# 1 56.990511 2.761881 15.175078
# 2 56.990511 4.846484 15.785400
# 3 56.990511 6.812892 16.003521
# 4 56.990511 7.968746 16.361285
# 5 56.990511 10.050951 17.026923
# 6 56.990511 10.172123 17.386449
# 7 56.990511 9.746595 18.120633
# 8 56.990511 10.752841 18.008026
# 9 56.990511 13.581624 16.260911
# 10 56.990511 11.201048 17.514225
# 11 56.990511 13.934230 17.563789
# 12 58.750543 15.281997 17.265934
# 13 72.769839 16.103449 20.449349
# 14 72.769839 15.685849 20.781715
# 15 72.769839 15.367631 21.713353
# 16 72.769839 15.793875 21.005091
# 17 72.769839 18.404186 20.109835
# 18 72.769839 17.144001 20.772931
# 19 72.769839 15.766175 21.940473
# 20 72.769839 16.607348 21.700038
# 21 72.769839 18.869300 21.722987
# 22 72.769839 17.546840 22.085735
# 23 72.769839 20.181084 20.968039
# 24 72.769839 23.796977 24.196448
# 25 72.769839 23.741938 24.809056
# 26 72.769839 23.147878 25.087259
# 27 72.769839 24.234095 24.212315
# 28 72.769839 23.777993 24.611612
# 29 72.769839 21.995853 26.150681
# 30 72.769839 24.320808 25.174419
# 31 72.769839 22.816150 25.605801
# 32 72.769839 24.194118 25.612593
# 33 72.769839 25.538544 25.597853
# 34 72.769839 24.645871 26.080857
# 35 72.769839 26.310437 26.132670
# 36 72.769839 26.173482 26.489708
# 37 72.769839 24.962654 28.298339
# 38 72.769839 25.879563 27.193142
# 39 72.769839 28.290545 26.368392
# 40 72.769839 25.679069 28.304001
# 41 72.769839 27.483825 27.201661
# 42 72.769839 26.134941 28.542297
# 43 72.769839 26.965942 27.090557
# 44 72.769839 29.645494 25.810861
# 45 72.769839 30.467605 25.857445
# 46 72.769839 29.911355 28.178352
# 47 72.769839 30.253076 28.839468
# 48 72.769839 29.142482 29.354084
# 49 72.769839 31.435786 27.540708
# 50 72.769839 29.975824 29.459121
# 51 72.769839 32.140901 28.032235
# 52 72.769839 32.400728 28.253258
# 53 72.769839 30.737938 31.014267
# 54 72.769839 29.122539 30.138379
# 55 72.769839 31.412840 28.988287
# 56 72.769839 32.292552 28.946533
# 57 72.769839 28.446585 30.579734
# 58 72.769839 31.925289 28.245844
# 59 72.769839 30.714246 29.613161
# 60 72.769839 32.665724 27.337286
# 61 72.769839 30.063025 30.447694
# 62 72.769839 30.403500 28.900913
# 63 72.769839 33.174675 27.287551
# 64 72.769839 30.656393 28.567470
# 65 72.769839 32.189698 28.673448
# 66 72.769839 29.621729 29.798335
# 67 72.769839 30.726184 28.748868
# 68 72.769839 30.996361 29.045947
# 69 72.769839 30.967532 28.906977
# 70 84.709436 35.296749 28.695795
# 71 84.709436 36.497425 27.808435
# 72 84.709436 35.860156 27.823255
# 73 84.709436 31.613189 30.147123
# 74 84.709436 34.679304 27.873559
# 75 84.709436 32.629962 30.317693
# 76 84.709436 33.324586 29.272391
# 77 84.709436 31.560951 30.887598
# 78 84.709436 32.909713 29.738023
# 79 84.709436 34.347340 29.454660
# 80 84.709436 29.253208 32.211199
# 81 84.709436 34.005103 30.521232
# 82 84.709436 33.971548 29.794863
# 83 84.709436 33.922853 29.838339
# 84 84.709436 33.427273 29.930158
# 85 84.709436 30.464556 32.104328
# 86 84.709436 32.681748 30.599451
# 87 84.709436 33.611031 29.939714
# 88 84.709436 32.346735 30.532258
# 89 84.709436 35.326877 29.185982
# 90 84.709436 31.991892 30.272067
# 91 84.709436 32.291202 30.850714
# 92 84.709436 32.767972 30.857337
# 93 84.709436 31.072868 31.201414
# 94 84.709436 31.719570 30.811302
# 95 84.709436 32.228275 31.785884
# 96 84.709436 32.325731 30.822288
# 97 84.709436 31.824044 30.625365
# 98 84.709436 33.926162 29.975729
# 99 84.709436 33.201874 29.720623
# Best solution saved as single_island_optimization/models/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt with fitness: 84.709436
# Running evolution iteration 2
# 0 40.846745 -1.733721 9.991120
# 1 40.846745 0.834061 10.751294
# 2 40.846745 3.601753 11.506027
# 3 55.847522 7.252398 13.925179
# 4 55.847522 9.249294 13.945670
# 5 55.847522 11.083585 14.738364
# 6 55.847522 10.894011 15.720803
# 7 55.847522 11.583388 15.956686
# 8 55.847522 12.165723 16.937176
# 9 55.847522 12.925475 16.372676
# 10 55.847522 11.788895 17.398919
# 11 55.847522 10.752553 17.845210
# 12 66.423928 14.888938 18.364547
# 13 66.423928 14.141388 18.947956
# 14 66.423928 13.826254 19.132413
# 15 66.423928 12.889243 19.227941
# 16 69.795409 15.605522 20.217363
# 17 69.795409 14.005448 21.315965
# 18 69.795409 14.858206 20.488647
# 19 69.795409 15.111642 21.470855
# 20 69.795409 16.272329 21.313938
# 21 69.795409 15.239745 21.950040
# 22 69.795409 17.737672 20.954685
# 23 69.795409 16.127972 22.183480
# 24 69.795409 16.793911 22.313246
# 25 69.795409 15.606409 22.425551
# 26 69.795409 16.751399 23.007502
# 27 69.795409 21.827235 21.813314
# 28 69.795409 19.252235 23.242831
# 29 69.795409 19.741851 22.493312
# 30 69.795409 19.574189 23.041459
# 31 69.795409 19.297567 23.485536
# 32 69.795409 20.441920 23.348592
# 33 69.795409 20.092019 22.968260
# 34 69.795409 20.624647 23.700651
# 35 69.795409 20.419736 23.663214
# 36 69.795409 25.492940 22.044516
# 37 69.795409 21.186393 24.414791
# 38 69.795409 22.503854 23.361631
# 39 69.795409 23.494718 23.877254
# 40 69.795409 22.756686 24.517054
# 41 69.795409 23.132127 24.783134
# 42 69.795409 23.826412 24.187165
# 43 69.795409 24.619466 23.883173
# 44 72.677024 24.712511 26.564684
# 45 72.677024 25.255102 25.872546
# 46 72.677024 24.876280 26.240311
# 47 72.677024 23.175521 28.579970
# 48 72.677024 25.595883 26.207599
# 49 72.677024 27.399223 27.083317
# 50 72.677024 27.221659 27.602516
# 51 72.677024 26.499907 27.422175
# 52 72.677024 26.078676 27.758386
# 53 72.677024 25.472002 28.079475
# 54 72.677024 29.860478 25.788773
# 55 72.677024 28.602299 27.088442
# 56 72.677024 26.048238 28.358807
# 57 72.677024 29.306241 26.572547
# 58 72.677024 27.684147 28.076702
# 59 72.677024 28.560512 28.236172
# 60 72.677024 29.161304 27.445970
# 61 72.677024 28.469749 27.602915
# 62 72.677024 26.877159 28.299294
# 63 72.677024 26.891645 28.576670
# 64 72.677024 27.205134 28.366743
# 65 72.677024 30.675694 27.112230
# 66 72.677024 28.065600 28.116021
# 67 72.677024 30.169623 28.170711
# 68 72.677024 26.597539 30.366064
# 69 72.677024 28.011295 30.584676
# 70 72.677024 31.342016 30.155988
# 71 72.677024 34.620551 27.910272
# 72 72.677024 35.269255 27.190398
# 73 72.677024 30.757866 29.627286
# 74 72.677024 31.956147 29.518067
# 75 72.677024 30.203167 30.993926
# 76 72.677024 31.267178 29.365463
# 77 72.677024 30.497873 31.133388
# 78 72.677024 33.719199 29.355515
# 79 72.677024 32.715518 29.528153
# 80 72.677024 31.941191 30.341385
# 81 72.677024 31.624165 30.626965
# 82 72.677024 34.626835 29.379265
# 83 72.677024 36.673103 27.929272
# 84 72.677024 36.143493 27.381309
# 85 72.677024 33.355598 28.848016
# 86 72.677024 30.453593 31.375011
# 87 72.677024 34.577498 29.431444
# 88 72.677024 30.607529 31.572395
# 89 72.677024 31.423845 30.324108
# 90 72.677024 31.865627 30.793024
# 91 72.677024 32.279246 29.672095
# 92 72.677024 34.273655 29.210664
# 93 72.677024 32.629818 29.928854
# 94 72.677024 30.656732 31.658410
# 95 72.677024 34.217819 29.666844
# 96 72.677024 36.854025 28.621031
# 97 72.677024 37.426993 26.665176
# 98 72.677024 32.853475 30.641168
# 99 72.677024 34.849672 29.447862
# Best solution saved as single_island_optimization/models/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt with fitness: 72.677024
# Running evolution iteration 3
# 0 44.713834 -0.630019 11.023049
# 1 44.713834 2.302431 11.947517
# 2 44.713834 4.339241 13.236692
# 3 44.713834 6.106641 13.671439
# 4 44.713834 6.282340 14.266984
# 5 44.713834 8.805852 13.826943
# 6 44.713834 7.451176 14.478198
# 7 44.713834 9.802426 14.021265
# 8 44.713834 12.826991 13.747198
# 9 44.713834 13.108223 15.481538
# 10 44.713834 14.077262 17.385509
# 11 44.713834 17.409971 16.457678
# 12 44.713834 16.638576 17.310757
# 13 44.713834 15.250865 18.869136
# 14 44.713834 15.210797 18.288973
# 15 44.713834 18.247087 17.679812
# 16 44.713834 17.297878 19.215952
# 17 44.713834 17.915164 18.760055
# 18 58.547267 21.906820 18.413715
# 19 58.547267 19.790385 19.982034
# 20 58.547267 19.886447 19.669321
# 21 58.547267 19.764642 19.296615
# 22 58.547267 17.620265 21.135734
# 23 58.547267 21.125695 18.633975
# 24 58.547267 23.415735 19.486174
# 25 58.547267 21.138571 20.021265
# 26 58.547267 21.213481 20.330247
# 27 58.547267 20.476584 20.757371
# 28 58.547267 19.255366 22.517559
# 29 58.547267 22.250569 19.815586
# 30 58.547267 21.485441 20.183057
# 31 58.547267 21.483376 20.903855
# 32 58.547267 22.557201 19.896014
# 33 58.547267 22.050306 20.549503
# 34 58.547267 19.934526 22.365094
# 35 58.547267 23.497863 21.331612
# 36 58.547267 23.567821 20.708737
# 37 58.547267 21.198213 22.138119
# 38 58.547267 24.138852 19.702887
# 39 58.547267 21.059701 21.763352
# 40 58.547267 22.056851 21.293518
# 41 58.547267 23.346573 20.404125
# 42 58.547267 20.527678 22.022237
# 43 58.547267 21.896717 22.113085
# 44 58.547267 22.862234 23.070843
# 45 58.547267 22.637281 22.146695
# 46 58.547267 24.869696 21.580338
# 47 58.547267 20.542945 24.090217
# 48 58.547267 20.948978 23.344313
# 49 58.547267 21.383713 23.223837
# 50 58.547267 21.863707 22.796959
# 51 58.547267 21.862514 22.777287
# 52 58.547267 21.227498 22.697190
# 53 58.547267 24.930572 21.211359
# 54 58.547267 26.017555 20.972074
# 55 58.547267 21.327657 23.482987
# 56 58.547267 26.063233 21.428703
# 57 58.641520 25.508518 23.069158
# 58 58.641520 24.336880 23.709649
# 59 58.641520 25.116362 23.153494
# 60 58.641520 24.222120 24.082789
# 61 58.641520 24.247114 24.067275
# 62 58.641520 25.960941 23.939709
# 63 60.614424 25.013796 24.353810
# 64 60.614424 25.918461 23.936708
# 65 60.614424 26.071958 23.442446
# 66 60.614424 25.357556 24.854364
# 67 60.614424 24.607583 25.033512
# 68 60.614424 26.569082 23.872257
# 69 60.614424 26.308259 24.040282
# 70 60.614424 26.198855 24.388861
# 71 60.614424 28.869696 24.123378
# 72 60.614424 27.354500 24.926345
# 73 60.614424 24.826358 26.013271
# 74 60.614424 27.685039 25.089913
# 75 60.614424 29.429356 23.820580
# 76 62.609743 28.923139 26.140323
# 77 62.609743 30.150957 25.690815
# 78 66.344064 29.855518 26.190646
# 79 66.344064 29.419806 27.561140
# 80 66.344064 28.131225 27.528234
# 81 66.344064 28.400101 27.139173
# 82 73.169926 29.818552 28.502773
# 83 73.169926 32.390473 27.300466
# 84 73.169926 31.230912 28.295243
# 85 73.169926 32.894022 29.626952
# 86 73.169926 30.791673 30.334210
# 87 73.169926 32.827464 29.641748
# 88 73.169926 32.319641 29.195598
# 89 73.169926 32.099460 29.506297
# 90 73.169926 31.090282 29.306425
# 91 73.169926 32.749852 29.093259
# 92 73.169926 33.271937 29.745545
# 93 73.169926 34.567324 28.362876
# 94 73.169926 29.717583 31.994888
# 95 73.169926 30.698736 31.079852
# 96 73.169926 34.002363 28.733112
# 97 73.169926 33.259908 28.858953
# 98 73.169926 32.016787 30.060581
# 99 73.169926 31.178351 30.161655
# Best solution saved as single_island_optimization/models/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt with fitness: 73.169926
# Running evolution iteration 4
# 0 30.380739 -0.616350 9.410243
# 1 35.577006 1.322058 11.409261
# 2 69.951978 4.276196 15.373637
# 3 69.951978 6.770942 15.934441
# 4 69.951978 11.210062 15.623845
# 5 69.951978 12.167957 16.208479
# 6 69.951978 10.854487 17.604779
# 7 72.293476 14.643061 19.625100
# 8 72.293476 15.390292 19.584816
# 9 72.293476 16.741512 19.678416
# 10 72.293476 17.918631 20.413360
# 11 72.293476 17.730572 21.584620
# 12 72.293476 21.317280 21.166863
# 13 72.293476 20.959455 22.007539
# 14 72.293476 23.472474 22.830746
# 15 72.293476 22.157521 22.195977
# 16 72.293476 19.789485 24.268030
# 17 72.293476 21.112540 23.802653
# 18 72.293476 21.835439 23.429749
# 19 72.293476 23.666692 22.738465
# 20 72.293476 22.165994 24.124842
# 21 72.293476 21.270371 24.261370
# 22 72.293476 24.530175 22.739044
# 23 72.293476 22.457390 23.384381
# 24 72.293476 22.087153 23.911315
# 25 72.293476 23.590955 23.015692
# 26 72.293476 22.598486 23.422905
# 27 72.293476 25.737060 22.676558
# 28 72.293476 25.970483 23.302683
# 29 72.293476 20.640396 26.019665
# 30 72.293476 22.242301 24.877430
# 31 72.293476 26.185486 23.644679
# 32 72.293476 25.409085 24.861405
# 33 72.293476 25.357665 24.394813
# 34 72.293476 24.840157 24.477579
# 35 72.293476 26.747711 25.252532
# 36 72.293476 28.585848 23.554275
# 37 72.293476 28.832604 23.129980
# 38 72.293476 25.034240 25.867673
# 39 72.293476 25.532941 25.484374
# 40 72.293476 26.146607 25.890036
# 41 72.293476 26.415216 25.167047
# 42 72.293476 24.794251 26.233045
# 43 72.293476 26.795780 25.237368
# 44 72.293476 23.498847 26.996228
# 45 72.293476 24.746291 26.414932
# 46 72.293476 22.852458 27.272391
# 47 72.293476 25.222460 26.385622
# 48 72.293476 26.156195 25.950455
# 49 72.293476 25.775482 27.003274
# 50 72.293476 25.923242 27.009332
# 51 72.293476 27.739968 26.328864
# 52 72.293476 26.958654 26.325779
# 53 72.293476 26.349415 26.426172
# 54 72.293476 26.276437 26.613438
# 55 72.293476 25.387350 27.381564
# 56 72.293476 26.765672 26.190488
# 57 72.293476 25.658784 26.990276
# 58 72.293476 28.465256 26.624891
# 59 72.293476 28.621858 26.615924
# 60 72.293476 27.132824 27.373676
# 61 72.293476 27.627118 27.596699
# 62 72.293476 27.345880 27.578367
# 63 72.293476 29.193591 26.957135
# 64 72.293476 29.267358 26.603687
# 65 72.293476 28.316308 27.128175
# 66 72.293476 27.931265 28.204809
# 67 72.293476 30.746478 26.999951
# 68 72.293476 29.781549 27.469664
# 69 72.293476 28.277650 28.302833
# 70 72.293476 28.757333 27.881314
# 71 72.293476 28.277323 27.916791
# 72 72.293476 28.203579 28.323873
# 73 72.293476 28.013528 28.902720
# 74 72.293476 31.778287 27.313349
# 75 72.293476 31.921153 27.178639
# 76 72.293476 31.231713 28.258138
# 77 72.293476 30.704503 27.931388
# 78 72.293476 30.435269 27.902860
# 79 85.933702 36.779846 27.400382
# 80 85.933702 30.967672 30.921046
# 81 85.933702 33.432402 29.317840
# 82 85.933702 33.819071 30.669132
# 83 85.933702 32.828763 30.987570
# 84 85.933702 31.011972 31.343354
# 85 85.933702 31.776989 31.121089
# 86 85.933702 33.188009 31.224160
# 87 85.933702 32.262747 31.387578
# 88 85.933702 32.669313 30.321441
# 89 85.933702 34.181982 29.857580
# 90 85.933702 30.546513 32.530686
# 91 85.933702 35.376029 29.768161
# 92 85.933702 34.306186 29.510640
# 93 85.933702 35.460139 29.602295
# 94 85.933702 33.136741 31.026540
# 95 85.933702 33.551494 30.363724
# 96 85.933702 35.802106 29.420908
# 97 85.933702 32.434966 31.732219
# 98 85.933702 32.860284 31.239714
# 99 85.933702 31.950489 32.560359
# Best solution saved as single_island_optimization/models/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt with fitness: 85.933702
# Running evolution iteration 5
# 0 43.281029 0.537338 9.447696
# 1 43.281029 1.364815 10.380911
# 2 43.281029 3.680265 11.932229
# 3 43.281029 7.516327 10.800379
# 4 50.275384 9.229905 13.072521
# 5 50.275384 8.743988 14.197250
# 6 50.275384 8.809801 14.288061
# 7 50.275384 9.942290 14.102923
# 8 50.275384 11.549212 14.180446
# 9 50.275384 11.069146 14.261429
# 10 50.275384 10.903041 15.523868
# 11 50.275384 12.425146 14.500679
# 12 50.275384 12.073693 15.551056
# 13 50.275384 13.815386 14.760314
# 14 69.978969 15.651186 18.930852
# 15 69.978969 12.943324 20.620266
# 16 69.978969 16.792309 19.098267
# 17 69.978969 14.181995 20.145225
# 18 69.978969 14.236135 20.325026
# 19 69.978969 15.402403 19.754415
# 20 69.978969 16.035206 19.842871
# 21 69.978969 14.524772 20.640918
# 22 69.978969 14.444986 20.726319
# 23 69.978969 14.637957 20.815778
# 24 69.978969 17.327973 19.291069
# 25 69.978969 17.955888 19.904455
# 26 69.978969 16.480739 20.454801
# 27 69.978969 17.385889 20.637271
# 28 69.978969 17.830729 20.637617
# 29 69.978969 18.187030 20.667970
# 30 69.978969 16.966261 20.824817
# 31 69.978969 16.475461 21.097424
# 32 69.978969 19.215597 22.722377
# 33 69.978969 17.131801 23.691634
# 34 69.978969 19.838355 23.007479
# 35 69.978969 19.523199 23.090472
# 36 69.978969 19.182743 23.237371
# 37 69.978969 20.699325 22.744144
# 38 69.978969 19.913569 23.906397
# 39 78.679270 22.077145 25.150559
# 40 78.679270 21.715061 25.067339
# 41 78.679270 21.482775 24.844651
# 42 78.679270 22.149724 25.180743
# 43 78.679270 23.261464 24.946447
# 44 78.679270 21.282149 25.899608
# 45 78.679270 24.923189 24.436777
# 46 78.679270 23.968296 25.380041
# 47 78.679270 22.263780 26.088063
# 48 78.679270 22.371915 26.894757
# 49 78.679270 24.086442 24.692028
# 50 78.679270 22.947019 25.814541
# 51 78.679270 25.868898 25.533206
# 52 78.679270 23.838361 26.638777
# 53 78.679270 23.893474 26.465722
# 54 78.679270 28.697264 25.288514
# 55 78.679270 25.522414 26.943203
# 56 78.679270 28.037213 26.245311
# 57 78.679270 28.114657 26.050010
# 58 78.679270 27.579713 26.119474
# 59 78.679270 26.228156 27.178695
# 60 78.679270 26.089811 26.899779
# 61 78.679270 24.800405 27.978999
# 62 78.679270 25.397438 27.955442
# 63 78.679270 25.899882 27.243345
# 64 78.679270 25.316022 27.567471
# 65 78.679270 26.005073 28.862555
# 66 78.679270 26.457721 27.950882
# 67 78.679270 28.147139 26.656135
# 68 78.679270 27.941186 27.950078
# 69 78.679270 28.958508 26.222000
# 70 78.679270 27.632763 26.951671
# 71 78.679270 27.887818 27.497313
# 72 78.679270 28.235477 26.812294
# 73 78.679270 26.386093 28.045304
# 74 78.679270 27.348959 27.475289
# 75 78.679270 27.454796 27.784116
# 76 78.679270 25.725181 28.544621
# 77 78.679270 26.407359 28.353991
# 78 78.679270 25.501345 28.572236
# 79 78.679270 27.902203 28.261900
# 80 78.679270 27.306927 28.172313
# 81 78.679270 27.346856 28.160810
# 82 78.679270 27.097548 28.146797
# 83 78.679270 27.984087 28.093108
# 84 78.679270 27.671719 28.294493
# 85 78.679270 26.345170 28.906895
# 86 78.679270 30.009971 26.693991
# 87 78.679270 28.778017 28.277558
# 88 78.679270 27.868961 29.128468
# 89 78.679270 28.295225 29.799121
# 90 78.679270 26.799880 30.140515
# 91 78.679270 29.451813 28.610073
# 92 78.679270 26.989333 30.444422
# 93 78.679270 27.189766 30.421865
# 94 78.679270 28.404723 29.258752
# 95 78.679270 26.410935 30.694193
# 96 78.679270 28.432785 29.055491
# 97 78.679270 29.703379 29.814922
# 98 78.679270 29.628578 30.722739
# 99 78.679270 32.683140 30.051672
# Best solution saved as single_island_optimization/models/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt with fitness: 78.679270
# Running evolution iteration 6
# 0 52.267130 -1.556538 10.454738
# 1 52.267130 1.188223 12.121983
# 2 52.267130 3.041366 12.637944
# 3 52.267130 3.089035 13.853923
# 4 52.267130 6.755454 13.654754
# 5 52.267130 8.625873 13.282494
# 6 52.267130 10.734075 14.305757
# 7 52.267130 11.370162 15.226727
# 8 52.267130 9.430499 16.008834
# 9 52.267130 12.472237 15.061170
# 10 52.267130 9.939623 16.653722
# 11 52.267130 12.266579 16.035311
# 12 52.267130 12.485875 15.813197
# 13 52.267130 14.993598 15.495970
# 14 52.267130 15.734385 15.360124
# 15 52.267130 14.502448 17.658832
# 16 52.267130 14.814386 17.709141
# 17 52.267130 14.983218 18.340427
# 18 52.267130 14.518015 18.699388
# 19 52.267130 15.754352 18.345637
# 20 52.267130 17.373284 17.899000
# 21 52.267130 17.790099 18.347418
# 22 52.267130 17.434237 19.186960
# 23 52.267130 16.756531 19.894251
# 24 52.267130 19.649991 18.476495
# 25 52.267130 18.411380 18.401375
# 26 52.267130 15.520012 20.851241
# 27 60.734496 18.412275 22.090129
# 28 60.734496 19.891913 21.012145
# 29 60.734496 23.910164 18.630891
# 30 60.734496 18.587135 21.799135
# 31 60.734496 20.357196 21.329352
# 32 60.734496 19.602283 22.187807
# 33 60.734496 21.250428 21.301076
# 34 60.734496 20.122860 21.415534
# 35 60.734496 22.460620 20.138108
# 36 60.734496 24.016057 18.744666
# 37 66.162589 24.400675 21.701203
# 38 66.162589 23.316822 23.239135
# 39 66.162589 21.779809 24.011012
# 40 66.162589 25.259937 21.561893
# 41 66.162589 23.473400 23.683530
# 42 66.162589 25.686699 22.734674
# 43 66.162589 28.522639 22.531066
# 44 66.162589 26.145991 23.233754
# 45 66.162589 26.156577 24.000128
# 46 66.162589 25.490126 24.872482
# 47 66.162589 25.133456 25.475229
# 48 66.162589 25.054362 24.895856
# 49 66.162589 26.905470 24.852948
# 50 66.162589 28.204789 24.782911
# 51 66.162589 27.293620 26.700745
# 52 66.162589 28.623841 25.134013
# 53 66.162589 28.815196 25.523631
# 54 66.162589 29.167283 26.017695
# 55 66.162589 34.395970 21.921900
# 56 66.162589 31.209725 24.012548
# 57 66.162589 33.111186 23.712214
# 58 66.162589 31.969376 25.127148
# 59 66.162589 30.764241 25.463159
# 60 66.162589 30.133720 26.323800
# 61 66.162589 31.892899 25.853358
# 62 66.162589 31.722847 25.645588
# 63 66.162589 31.312869 25.050546
# 64 66.162589 32.500959 25.099437
# 65 66.162589 35.596091 23.006852
# 66 66.775684 33.994461 24.470387
# 67 66.775684 28.063111 28.250182
# 68 66.775684 32.160785 26.428423
# 69 66.775684 31.861798 26.795319
# 70 66.775684 31.904900 27.487616
# 71 66.775684 31.764824 28.254632
# 72 66.775684 31.970902 27.553538
# 73 66.942275 35.796245 26.131329
# 74 66.942275 32.928525 27.929738
# 75 66.942275 31.855964 27.885439
# 76 66.942275 34.895863 27.441707
# 77 66.942275 33.086908 26.541550
# 78 66.942275 32.676491 27.484314
# 79 66.942275 39.473153 25.953869
# 80 66.942275 33.884497 26.578884
# 81 66.942275 34.316845 26.938574
# 82 66.942275 32.827676 27.747139
# 83 66.942275 31.439271 28.538421
# 84 66.942275 33.999032 27.669086
# 85 72.489719 36.780631 25.788728
# 86 72.489719 37.367300 25.936154
# 87 72.489719 33.793618 30.389213
# 88 72.489719 36.562652 27.936325
# 89 72.489719 34.329183 29.814051
# 90 72.489719 33.608480 30.143507
# 91 72.489719 32.600075 31.159461
# 92 72.489719 36.055069 28.352500
# 93 72.489719 32.951791 29.948393
# 94 72.489719 33.594766 29.551816
# 95 72.489719 34.013069 29.466746
# 96 72.489719 36.348685 29.325727
# 97 72.904269 37.375886 27.966928
# 98 72.904269 33.913198 29.612932
# 99 72.904269 38.307575 27.520266
# Best solution saved as single_island_optimization/models/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt with fitness: 72.904269
# Running evolution iteration 7
# 0 52.557744 -1.802026 8.577591
# 1 52.557744 0.959497 10.352022
# 2 52.557744 2.710643 11.541380
# 3 66.501752 5.444700 14.999782
# 4 66.501752 5.319768 15.556186
# 5 66.501752 6.570234 15.453997
# 6 66.501752 6.259646 15.508521
# 7 66.501752 7.239601 15.641494
# 8 66.501752 9.542798 16.498808
# 9 66.501752 10.784714 16.879823
# 10 66.501752 10.939912 17.704777
# 11 66.501752 12.088156 17.589974
# 12 66.501752 11.234186 17.912761
# 13 66.501752 12.822338 17.086950
# 14 66.501752 12.933639 18.358999
# 15 66.501752 14.423977 17.157249
# 16 66.501752 14.686078 17.171206
# 17 66.501752 14.892653 17.879484
# 18 66.501752 14.997014 18.335923
# 19 66.501752 17.270516 19.680544
# 20 66.501752 18.012476 20.746216
# 21 66.501752 18.928814 23.169931
# 22 66.501752 19.467369 22.207292
# 23 66.501752 20.062595 22.221130
# 24 66.501752 20.177507 22.635955
# 25 66.722901 24.272713 21.864779
# 26 66.722901 23.793133 22.457992
# 27 66.722901 27.119089 23.870286
# 28 66.722901 26.004484 25.322940
# 29 72.321544 26.282113 26.736508
# 30 72.321544 29.536496 25.733596
# 31 72.321544 29.804363 25.706214
# 32 72.321544 29.746856 25.993802
# 33 72.321544 32.423969 25.551443
# 34 72.321544 31.925262 26.967208
# 35 72.321544 31.869553 27.778588
# 36 72.321544 32.257352 27.633644
# 37 72.321544 32.832256 28.081635
# 38 72.321544 33.878081 27.116530
# 39 72.321544 32.360565 28.346345
# 40 72.321544 32.067923 28.143001
# 41 72.321544 31.418200 28.600277
# 42 72.321544 29.412108 30.245427
# 43 72.321544 32.394782 29.419338
# 44 72.321544 29.509566 30.758943
# 45 72.321544 28.818766 31.150571
# 46 72.321544 31.417981 30.082685
# 47 72.988351 33.852364 29.745147
# 48 72.988351 35.647697 28.339417
# 49 72.988351 31.778515 31.084340
# 50 72.988351 33.283119 29.865915
# 51 72.988351 32.077121 31.266945
# 52 72.988351 33.987893 29.567747
# 53 72.988351 33.930218 29.959835
# 54 72.988351 35.558089 29.601965
# 55 72.988351 35.016704 29.202374
# 56 72.988351 34.566677 30.385180
# 57 72.988351 32.120470 31.119397
# 58 72.988351 36.156600 29.495401
# 59 72.988351 34.733122 29.397245
# 60 72.988351 34.489314 30.908202
# 61 72.988351 32.726314 30.352320
# 62 73.020428 36.833057 32.194135
# 63 73.020428 37.933830 29.424928
# 64 85.364261 36.315971 31.911942
# 65 85.364261 37.766025 30.353843
# 66 85.364261 36.445070 31.413164
# 67 85.462408 34.530396 34.656229
# 68 85.462408 36.983826 33.224719
# 69 85.462408 35.375762 34.483940
# 70 85.462408 39.083878 31.427288
# 71 85.462408 40.877335 29.315422
# 72 85.462408 37.034800 32.097029
# 73 85.462408 36.351901 33.348229
# 74 85.462408 39.703412 32.213684
# 75 85.462408 38.765615 32.360732
# 76 85.462408 38.653290 33.156493
# 77 85.462408 36.992068 33.352523
# 78 85.462408 34.896111 35.366981
# 79 85.462408 40.069863 33.208842
# 80 85.462408 41.180091 31.838088
# 81 85.462408 43.326446 31.916495
# 82 85.462408 38.512136 33.774643
# 83 85.462408 42.315850 33.110304
# 84 85.462408 41.695226 31.682524
# 85 85.462408 41.682099 31.222225
# 86 85.462408 39.759253 32.962940
# 87 85.462408 39.250894 33.400402
# 88 85.462408 42.004306 31.402626
# 89 85.462408 35.844099 35.774533
# 90 85.462408 40.270074 32.127623
# 91 85.462408 39.599413 33.119731
# 92 85.462408 37.402113 34.841145
# 93 85.462408 40.639554 34.046785
# 94 85.462408 40.572959 32.041343
# 95 85.462408 39.231291 34.435907
# 96 85.462408 40.095418 32.891308
# 97 85.462408 37.741060 34.037172
# 98 85.462408 39.901065 32.620812
# 99 85.462408 38.103623 34.540344
# Best solution saved as single_island_optimization/models/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt with fitness: 85.462408
# Running evolution iteration 8
# 0 25.102825 -1.605003 8.287558
# 1 25.102825 0.836651 9.115018
# 2 34.371098 3.841582 11.051583
# 3 34.371098 4.640613 12.519163
# 4 34.371098 6.380782 12.164384
# 5 34.371098 7.596219 12.884517
# 6 34.371098 8.846276 13.287079
# 7 34.371098 9.592423 12.317342
# 8 34.371098 9.753909 13.016281
# 9 34.371098 10.320810 13.218390
# 10 34.371098 10.964697 14.327073
# 11 34.371098 11.175854 13.911673
# 12 37.860577 11.007636 15.046887
# 13 37.860577 11.332155 15.135513
# 14 37.860577 10.161735 16.433248
# 15 37.860577 10.058336 16.201703
# 16 37.860577 12.626434 15.059699
# 17 37.860577 14.038871 14.784248
# 18 37.860577 12.078626 16.829527
# 19 37.860577 14.186960 16.311113
# 20 37.860577 13.423464 16.637438
# 21 37.860577 13.450800 16.664553
# 22 42.524527 14.599481 17.264705
# 23 42.524527 14.297940 18.023291
# 24 42.524527 18.605679 15.973125
# 25 42.524527 17.430115 16.880863
# 26 42.524527 16.086822 17.754985
# 27 66.831088 16.665798 19.929015
# 28 66.831088 19.654714 17.684089
# 29 66.831088 17.503513 20.197675
# 30 66.831088 19.220572 20.940894
# 31 66.831088 19.437831 21.416511
# 32 66.831088 19.251679 21.402074
# 33 66.831088 20.641195 20.728421
# 34 66.831088 20.631317 21.033483
# 35 66.831088 20.496960 20.032233
# 36 66.831088 17.919268 22.038073
# 37 66.831088 20.982019 21.969134
# 38 66.831088 20.333705 20.943563
# 39 66.831088 21.499935 22.422615
# 40 66.831088 19.470348 22.768522
# 41 66.831088 23.198126 20.757218
# 42 66.831088 23.323548 21.703487
# 43 66.831088 21.451269 22.002822
# 44 66.831088 20.917213 22.271112
# 45 66.831088 18.871167 23.877265
# 46 66.831088 20.211168 23.094385
# 47 66.831088 20.895418 22.190678
# 48 66.831088 22.029795 21.822526
# 49 66.831088 19.750634 22.953852
# 50 66.831088 23.908241 21.160995
# 51 66.831088 24.251214 22.141169
# 52 66.831088 23.819146 22.593618
# 53 66.831088 23.880280 22.978581
# 54 66.831088 22.278595 24.484912
# 55 66.831088 25.052701 22.422815
# 56 66.831088 23.784078 24.226486
# 57 66.831088 26.700532 22.222024
# 58 66.831088 23.973931 23.867491
# 59 66.831088 24.616221 23.193404
# 60 66.831088 27.996240 21.429426
# 61 66.831088 25.371074 23.434648
# 62 66.831088 25.901974 23.944151
# 63 66.831088 25.716175 23.785493
# 64 66.831088 25.902471 23.723187
# 65 66.831088 25.388254 23.703419
# 66 66.831088 26.708067 23.822507
# 67 66.831088 24.413490 24.911854
# 68 66.831088 24.650758 24.457304
# 69 66.831088 26.994042 24.123671
# 70 66.831088 27.719881 23.145568
# 71 66.831088 25.164410 24.396210
# 72 66.831088 25.244214 24.386133
# 73 66.831088 27.488876 24.206849
# 74 66.831088 27.051219 24.874058
# 75 69.810314 30.689589 24.025726
# 76 69.810314 29.769557 24.008189
# 77 69.810314 27.986906 25.010056
# 78 69.810314 30.217669 24.193495
# 79 69.810314 28.474432 24.972417
# 80 72.821617 28.440605 26.744178
# 81 72.821617 26.801065 27.646767
# 82 72.821617 27.052639 27.050711
# 83 72.821617 29.523893 26.816656
# 84 72.821617 29.331813 26.442166
# 85 72.821617 29.886791 26.871700
# 86 72.821617 30.903378 26.186849
# 87 72.821617 33.678605 26.314775
# 88 72.821617 34.742442 27.123744
# 89 72.821617 34.022376 26.818072
# 90 72.821617 30.172018 28.719581
# 91 72.821617 29.142456 29.786544
# 92 72.821617 32.319983 28.015945
# 93 72.821617 30.760184 29.672823
# 94 72.821617 30.910377 29.410651
# 95 72.821617 35.425982 26.959075
# 96 72.851786 34.488862 29.024644
# 97 72.851786 33.737152 29.153199
# 98 72.851786 31.905327 29.312465
# 99 72.851786 39.204624 24.777478
# Best solution saved as single_island_optimization/models/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt with fitness: 72.851786
# Running evolution iteration 9
# 0 37.048839 0.189271 10.343569
# 1 37.048839 3.780139 12.197285
# 2 43.407733 7.796856 12.964778
# 3 43.407733 8.742710 14.800276
# 4 43.407733 8.530124 15.767590
# 5 43.407733 10.491979 15.615278
# 6 43.407733 11.122535 15.975409
# 7 43.407733 12.072153 15.592352
# 8 43.407733 12.634036 15.946929
# 9 43.407733 11.310195 16.451480
# 10 43.407733 12.312244 16.191295
# 11 43.407733 10.588332 16.785241
# 12 43.407733 11.947588 16.602603
# 13 43.407733 11.554410 16.671203
# 14 54.186238 15.550723 17.939192
# 15 54.186238 19.810377 16.244614
# 16 54.186238 18.722518 18.618750
# 17 54.186238 19.790731 18.838288
# 18 54.186238 18.491868 19.457744
# 19 54.186238 20.085342 19.413843
# 20 54.186238 19.309257 20.302982
# 21 54.186238 18.751082 21.678464
# 22 54.186238 17.656564 21.726221
# 23 54.186238 17.746070 21.570778
# 24 54.186238 22.276285 18.844757
# 25 54.186238 20.005102 22.051704
# 26 54.186238 20.421333 21.449077
# 27 54.186238 19.858354 22.288021
# 28 54.186238 20.810183 21.105988
# 29 54.186238 20.381940 21.880921
# 30 70.290641 25.170749 20.554938
# 31 70.290641 21.782875 22.261457
# 32 70.290641 21.989904 23.601989
# 33 70.290641 22.485559 23.930423
# 34 70.290641 22.677512 24.599950
# 35 70.290641 20.466055 25.171323
# 36 70.290641 24.013288 23.059815
# 37 70.290641 21.413359 25.149160
# 38 70.290641 20.589685 25.596675
# 39 70.290641 24.542065 23.017338
# 40 70.290641 22.880627 24.315150
# 41 70.290641 24.430764 22.808444
# 42 70.290641 22.049395 25.582094
# 43 70.290641 23.947840 24.018178
# 44 70.290641 21.656932 25.306403
# 45 70.290641 23.980647 24.239905
# 46 70.290641 24.209838 23.639555
# 47 70.290641 26.516605 23.440981
# 48 70.290641 22.304066 25.907590
# 49 70.290641 23.433119 26.034786
# 50 70.290641 27.927921 23.267493
# 51 70.290641 26.019700 24.274628
# 52 70.290641 23.058472 25.340472
# 53 70.290641 22.355231 25.872807
# 54 70.290641 23.655129 25.204965
# 55 70.290641 23.728649 24.936962
# 56 70.290641 24.181940 24.972698
# 57 70.290641 26.999240 24.031184
# 58 70.290641 29.511696 23.797205
# 59 70.290641 25.828172 25.142947
# 60 70.290641 24.399774 26.050290
# 61 70.290641 25.635352 25.287017
# 62 70.290641 24.007908 25.841400
# 63 70.290641 29.564889 23.858457
# 64 70.290641 26.536116 26.432590
# 65 70.290641 27.074029 25.455753
# 66 70.290641 24.427840 26.245817
# 67 70.290641 26.506114 26.557622
# 68 70.290641 25.176120 26.456785
# 69 70.290641 24.348932 27.178751
# 70 70.290641 28.488239 24.486999
# 71 70.290641 25.633753 26.860106
# 72 70.290641 27.746971 26.432651
# 73 70.290641 25.383577 26.861220
# 74 70.290641 27.172362 25.802259
# 75 70.290641 25.469159 26.865025
# 76 70.290641 24.687525 28.029445
# 77 70.290641 26.854342 26.889984
# 78 79.078859 28.799841 27.294913
# 79 79.078859 27.730972 27.624695
# 80 79.078859 28.079884 27.428589
# 81 79.078859 28.169781 26.761752
# 82 79.078859 27.099598 29.265574
# 83 79.078859 26.702738 28.324802
# 84 79.078859 26.987084 29.041153
# 85 79.078859 27.467327 28.565789
# 86 79.078859 30.201894 26.660222
# 87 79.078859 26.261469 29.243913
# 88 79.078859 27.774369 29.624469
# 89 79.078859 31.981671 26.975008
# 90 79.078859 31.496659 25.867959
# 91 79.078859 30.115728 28.249158
# 92 79.078859 27.770443 29.138298
# 93 79.078859 28.701150 29.327622
# 94 79.078859 29.622178 28.433648
# 95 79.078859 29.039216 28.820739
# 96 79.078859 27.872339 30.171680
# 97 79.078859 32.495540 28.876034
# 98 79.078859 31.304418 28.549141
# 99 79.078859 30.600807 30.070373
# Best solution saved as single_island_optimization/models/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt with fitness: 79.078859
# Running evolution iteration 10
# 0 29.440810 -1.646086 7.273323
# 1 35.537556 1.098004 9.839586
# 2 47.924161 3.486848 12.194045
# 3 47.924161 4.930868 13.018947
# 4 47.924161 6.625963 14.604068
# 5 47.924161 8.009251 13.849908
# 6 47.924161 8.115187 14.418329
# 7 47.924161 10.219977 13.947486
# 8 47.924161 8.403385 15.927092
# 9 47.924161 9.335368 14.757527
# 10 47.924161 10.673265 15.191313
# 11 47.924161 11.219383 14.740376
# 12 47.924161 12.300762 15.083262
# 13 47.924161 11.168535 15.725078
# 14 47.924161 11.486428 15.362973
# 15 47.924161 12.555262 15.090196
# 16 47.924161 14.468132 16.072946
# 17 47.924161 13.301149 17.040660
# 18 47.924161 11.380404 17.985483
# 19 47.924161 14.603480 15.699641
# 20 47.924161 13.876780 16.439661
# 21 47.924161 14.316240 16.145214
# 22 48.405936 14.066802 17.882237
# 23 48.405936 13.976966 17.650509
# 24 48.405936 16.806890 16.683932
# 25 48.405936 14.441660 17.862418
# 26 48.405936 16.753865 17.558030
# 27 48.405936 16.161162 17.881012
# 28 48.405936 15.680336 18.178449
# 29 48.405936 16.674893 18.149880
# 30 48.405936 14.625643 19.713665
# 31 48.405936 16.884764 18.193676
# 32 48.405936 18.226409 17.467709
# 33 48.405936 16.576451 18.552844
# 34 48.405936 18.798032 18.866622
# 35 48.405936 19.944969 19.378546
# 36 48.405936 17.303753 20.122211
# 37 48.405936 19.464483 19.561197
# 38 48.405936 22.367691 17.751392
# 39 48.405936 22.890448 18.311435
# 40 48.405936 20.688526 19.475750
# 41 48.405936 19.726683 20.166089
# 42 48.405936 19.210108 21.177609
# 43 48.405936 20.025911 20.181291
# 44 48.405936 21.392495 20.298428
# 45 48.405936 19.691987 20.253820
# 46 48.405936 20.623680 20.774473
# 47 48.405936 22.910510 19.412529
# 48 48.405936 22.523755 19.545275
# 49 56.022865 25.345499 19.575446
# 50 56.022865 24.433175 19.506398
# 51 56.022865 21.725558 21.643983
# 52 64.131533 22.076308 23.007245
# 53 64.131533 22.670135 23.299929
# 54 64.131533 23.524759 22.661562
# 55 64.131533 25.524860 23.145428
# 56 64.131533 28.167456 21.783670
# 57 64.131533 23.996342 23.598610
# 58 64.131533 24.753547 23.702743
# 59 64.131533 26.014330 22.556622
# 60 64.131533 23.785994 24.036139
# 61 64.131533 27.370012 23.101518
# 62 64.131533 24.607993 23.877716
# 63 64.131533 26.191443 24.069246
# 64 64.131533 24.771024 24.789227
# 65 64.131533 24.749606 24.954700
# 66 64.131533 25.285033 23.902794
# 67 64.131533 27.417191 22.510403
# 68 64.131533 27.617434 23.814379
# 69 64.131533 26.837842 24.139707
# 70 64.131533 26.283654 23.916659
# 71 64.131533 25.127256 25.216095
# 72 64.131533 26.337296 24.209035
# 73 64.131533 29.506722 22.091865
# 74 64.131533 28.831366 23.171703
# 75 72.704227 30.915857 24.858684
# 76 72.704227 29.030545 25.744300
# 77 72.704227 31.934560 24.119484
# 78 72.704227 30.145744 25.984206
# 79 74.918961 30.615706 26.952490
# 80 74.918961 32.656404 24.666139
# 81 74.918961 30.069380 28.259381
# 82 74.918961 33.640883 25.789993
# 83 74.918961 32.415471 25.317836
# 84 74.918961 30.362472 28.685773
# 85 74.918961 32.152836 26.056834
# 86 74.918961 35.447208 24.875971
# 87 74.918961 35.194875 26.736252
# 88 74.918961 29.880597 28.655741
# 89 74.918961 32.348313 28.072508
# 90 74.918961 32.435029 27.657652
# 91 74.918961 35.017582 26.821952
# 92 78.881528 35.187318 28.362069
# 93 78.881528 30.590520 31.031538
# 94 78.881528 32.241227 29.992082
# 95 78.881528 36.313738 26.986282
# 96 78.881528 31.848636 30.281798
# 97 78.881528 34.012799 28.690328
# 98 78.881528 35.294974 27.803198
# 99 78.881528 33.738383 31.530641
# Best solution saved as single_island_optimization/models/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt with fitness: 78.881528

# %% [markdown]
# 测试

# %%
def test_loaded_model():
    # Hardcoded model file path
    filepath = f"{experiment_name}/models/SIModel_fitness25.078239_npop100_gens5_enemy[1, 2, 3, 4]_mut0.20_elitism0.20_20241015_204734.txt"

    fitness_scores = []
    gains = []  # Used to store individual_gain for each run

    # Load the saved model
    solution = load_best_solution(filepath)

    # Run 5 times
    for i in range(5):
        fitness, player_life, enemy_life = simulation_test(env, solution)
        fitness_scores.append(fitness)

        # Calculate individual_gain
        individual_gain = player_life - enemy_life
        gains.append(individual_gain)

        print(f"Run {i+1} fitness: {fitness}, individual_gain: {individual_gain}")

    # Calculate the average fitness
    average_fitness = np.mean(fitness_scores)
    average_gain = np.mean(gains)

    print(f"\nAverage fitness over 5 runs: {average_fitness}")
    print(f"Average individual gain over 5 runs: {average_gain}")


# # Run test
# test_loaded_model()


def evaluate_models(experiment_name, enemy):
    # Get all model files in the E{enemy} subfolder
    model_files = glob.glob(f"{experiment_name}/models/E{enemy}/*.txt")

    best_gain = -np.inf
    best_model = None
    best_model_gains = []

    for filepath in model_files:
        fitness_scores = []
        gains = []  # Used to store individual_gain for each run

        # Load the saved model
        solution = load_best_solution(filepath)

        # Run 5 times
        for i in range(10):
            fitness, player_life, enemy_life = simulation_test(env, solution)
            fitness_scores.append(fitness)

            # Calculate individual_gain
            individual_gain = player_life - enemy_life
            gains.append(individual_gain)

            print(
                f"Model: {filepath}, Run {i+1} fitness: {fitness}, individual_gain: {individual_gain}"
            )

        # Calculate the average fitness
        average_fitness = np.mean(fitness_scores)
        average_gain = np.mean(gains)

        print(f"\nModel: {filepath}, Average fitness over 5 runs: {average_fitness}")
        print(
            f"Model: {filepath}, Average individual gain over 5 runs: {average_gain}\n"
        )

        # Find the model with the best result
        if average_gain > best_gain:
            best_gain = average_gain
            best_model = filepath
            best_model_gains = gains

    print(f"Best model: {best_model} with average individual gain: {best_gain}")
    print(f"Best model's 10 individual gains: {best_model_gains}")
    # Save the best model's enemy and gain to a CSV file
    best_model_info_path = f"{experiment_name}/models/best_model_{experiment_name}_enemy_{enemy}.csv"
    with open(best_model_info_path, "w") as file:
        file.write("Enemy,Gain\n")
        for gain in best_model_gains:
            file.write(f"{enemy},{gain}\n")
    print(f"Best model info saved to {best_model_info_path}")

# %%
env.enemies=[1,2,3,4,5,6,7,8]
evaluate_models(experiment_name, 5678)
# Out:
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 1 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 2 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 3 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 4 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 5 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 6 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 7 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 8 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 9 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Run 10 fitness: 19.83742083622031, individual_gain: -0.01288099014290367
#
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Average fitness over 5 runs: 19.83742083622031
# Model: single_island_optimization/models/E5678/SIModel_fitness78.881528_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155638.txt, Average individual gain over 5 runs: -0.01288099014290367
#
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 1 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 2 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 3 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 4 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 5 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 6 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 7 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 8 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 9 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Run 10 fitness: 19.015637713230376, individual_gain: -0.6733376833163405
#
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Average fitness over 5 runs: 19.015637713230376
# Model: single_island_optimization/models/E5678/SIModel_fitness72.677024_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153850.txt, Average individual gain over 5 runs: -0.6733376833163405
#
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 1 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 2 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 3 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 4 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 5 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 6 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 7 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 8 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 9 fitness: 20.61727156150949, individual_gain: 7.143738354946933
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Run 10 fitness: 20.61727156150949, individual_gain: 7.143738354946933
#
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Average fitness over 5 runs: 20.61727156150949
# Model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt, Average individual gain over 5 runs: 7.143738354946933
#
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 1 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 2 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 3 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 4 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 5 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 6 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 7 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 8 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 9 fitness: 24.582033800976056, individual_gain: 6.963744529204675
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Run 10 fitness: 24.582033800976056, individual_gain: 6.963744529204675
#
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Average fitness over 5 runs: 24.582033800976056
# Model: single_island_optimization/models/E5678/SIModel_fitness85.462408_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155018.txt, Average individual gain over 5 runs: 6.963744529204675
#
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 1 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 2 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 3 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 4 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 5 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 6 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 7 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 8 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 9 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Run 10 fitness: 28.531780261363522, individual_gain: 1.0134731242382706
#
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Average fitness over 5 runs: 28.53178026136352
# Model: single_island_optimization/models/E5678/SIModel_fitness72.851786_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155225.txt, Average individual gain over 5 runs: 1.0134731242382706
#
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 1 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 2 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 3 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 4 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 5 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 6 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 7 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 8 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 9 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Run 10 fitness: 25.387967888641153, individual_gain: -1.4337331518642973
#
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Average fitness over 5 runs: 25.387967888641153
# Model: single_island_optimization/models/E5678/SIModel_fitness85.933702_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154337.txt, Average individual gain over 5 runs: -1.4337331518642973
#
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 1 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 2 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 3 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 4 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 5 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 6 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 7 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 8 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 9 fitness: 24.51282669976345, individual_gain: 1.285311631562248
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Run 10 fitness: 24.51282669976345, individual_gain: 1.285311631562248
#
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Average fitness over 5 runs: 24.51282669976345
# Model: single_island_optimization/models/E5678/SIModel_fitness73.169926_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154116.txt, Average individual gain over 5 runs: 1.285311631562248
#
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 1 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 2 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 3 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 4 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 5 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 6 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 7 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 8 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 9 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Run 10 fitness: 30.495739686180517, individual_gain: -1.5284231706330829
#
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Average fitness over 5 runs: 30.49573968618052
# Model: single_island_optimization/models/E5678/SIModel_fitness72.904269_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154813.txt, Average individual gain over 5 runs: -1.5284231706330829
#
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 1 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 2 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 3 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 4 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 5 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 6 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 7 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 8 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 9 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Run 10 fitness: 26.68948165750978, individual_gain: -1.7571416540519227
#
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Average fitness over 5 runs: 26.68948165750978
# Model: single_island_optimization/models/E5678/SIModel_fitness79.078859_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_155432.txt, Average individual gain over 5 runs: -1.7571416540519227
#
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 1 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 2 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 3 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 4 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 5 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 6 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 7 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 8 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 9 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Run 10 fitness: 21.873590792083917, individual_gain: 1.7118801553925849
#
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Average fitness over 5 runs: 21.873590792083917
# Model: single_island_optimization/models/E5678/SIModel_fitness78.679270_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_154555.txt, Average individual gain over 5 runs: 1.7118801553925849
#
# Best model: single_island_optimization/models/E5678/SIModel_fitness84.709436_npop100_gens100_enemy[5, 6, 7, 8]_mut0.20_elitism0.20_20241016_153637.txt with average individual gain: 7.143738354946933
# Best model's 10 individual gains: [7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933, 7.143738354946933]
# Best model info saved to single_island_optimization/models/best_model_info_enemy_5678.csv
